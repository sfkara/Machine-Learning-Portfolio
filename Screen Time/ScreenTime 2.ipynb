# %%
import cv2     # for capturing videos
import math   # for mathematical operations
import matplotlib.pyplot as plt    # for plotting the images
# %matplotlib inline
import pandas as pd
from keras.preprocessing import image   # for preprocessing the images
import numpy as np    # for mathematical operations
from keras.utils import np_utils
from skimage.transform import resize   # for resizing images
# Out:
# Using TensorFlow backend.

# %%
count = 0
videoFile = "Screen Time/Tom and jerry.mp4"
cap = cv2.VideoCapture(videoFile)   # capturing the video from the given path
frameRate = cap.get(5) #frame rate
x=1
while(cap.isOpened()):
    frameId = cap.get(1) #current frame number
    ret, frame = cap.read()
    if (ret != True):
        break
    if (frameId % math.floor(frameRate) == 0):
        filename ="frame%d.jpg" % count;count+=1
        cv2.imwrite(filename, frame)
cap.release()
print ("Done!")
# Out:
# Done!

# %%
img = plt.imread('frame81.jpg')   # reading image using its name
plt.imshow(img)

# %%
data = pd.read_csv('mapping.csv')     # reading the csv file
data.head()      # printing first five rows of the file
# Out:
#      Image_ID  Class
# 0  frame0.jpg      1
# 1  frame1.jpg      1
# 2  frame2.jpg      2
# 3  frame3.jpg      2
# 4  frame4.jpg      2

# %%
X = [ ]     # creating an empty array
for img_name in data.Image_ID:
    img = plt.imread('' + img_name)
    X.append(img)  # storing each image in array X
X = np.array(X)    # converting list to array

# %%
y = data.Class
dummy_y = np_utils.to_categorical(y)    # one hot encoding Classes

# %%
image = []
for i in range(0,X.shape[0]):
    a = resize(X[i], preserve_range=True, output_shape=(224,224)).astype(int)      # reshaping to 224*224*3
    image.append(a)
X = np.array(image)

# %%
from keras.applications.vgg16 import preprocess_input
X = preprocess_input(X, mode='tf')      # preprocessing the input data

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, dummy_y, test_size=0.3, random_state=42)    # preparing the validation set

# %%
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, InputLayer, Dropout
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))    # include_top=False to remove the top layer

# %%
X_train = base_model.predict(X_train)
X_valid = base_model.predict(X_valid)
X_train.shape, X_valid.shape
# Out:
# ((208, 7, 7, 512), (90, 7, 7, 512))

# %%
X_train = X_train.reshape(208, 7*7*512)      # converting to 1-D
X_valid = X_valid.reshape(90, 7*7*512)

# %%
train = X_train/X_train.max()      # centering the data
X_valid = X_valid/X_train.max()

# %%
# i. Building the model
model = Sequential()
model.add(InputLayer((7*7*512,)))    # input layer
model.add(Dense(units=1024, activation='sigmoid')) # hidden layer
model.add(Dense(3, activation='softmax'))    # output layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              25691136
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 25,694,211
# Trainable params: 25,694,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ii. Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# iii. Training the model
model.fit(train, y_train, epochs=100, validation_data=(X_valid, y_valid))
# Out:
# Train on 208 samples, validate on 90 samples
# Epoch 1/100
# 208/208 [==============================] - 3s 16ms/step - loss: 1.0278 - accuracy: 0.5962 - val_loss: 0.6411 - val_accuracy: 0.7111
# Epoch 2/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.3731 - accuracy: 0.8846 - val_loss: 0.5698 - val_accuracy: 0.7778
# Epoch 3/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.2139 - accuracy: 0.9038 - val_loss: 0.4027 - val_accuracy: 0.8222
# Epoch 4/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.1450 - accuracy: 0.9519 - val_loss: 0.3360 - val_accuracy: 0.8444
# Epoch 5/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0846 - accuracy: 0.9904 - val_loss: 0.3329 - val_accuracy: 0.8556
# Epoch 6/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0654 - accuracy: 0.9808 - val_loss: 0.4174 - val_accuracy: 0.8444
# Epoch 7/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0468 - accuracy: 0.9808 - val_loss: 0.3645 - val_accuracy: 0.8667
# Epoch 8/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0422 - accuracy: 0.9904 - val_loss: 0.3789 - val_accuracy: 0.8444
# Epoch 9/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0348 - accuracy: 0.9952 - val_loss: 0.3489 - val_accuracy: 0.8556
# Epoch 10/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0237 - accuracy: 0.9952 - val_loss: 0.3035 - val_accuracy: 0.8667
# Epoch 11/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0216 - accuracy: 0.9952 - val_loss: 0.3308 - val_accuracy: 0.8556
# Epoch 12/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0197 - accuracy: 0.9952 - val_loss: 0.3331 - val_accuracy: 0.8556
# Epoch 13/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0182 - accuracy: 0.9952 - val_loss: 0.3009 - val_accuracy: 0.8778
# Epoch 14/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.3345 - val_accuracy: 0.8556
# Epoch 15/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0165 - accuracy: 0.9952 - val_loss: 0.3237 - val_accuracy: 0.8667
# Epoch 16/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0164 - accuracy: 0.9904 - val_loss: 0.3230 - val_accuracy: 0.8667
# Epoch 17/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.3178 - val_accuracy: 0.8667
# Epoch 18/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.3253 - val_accuracy: 0.8556
# Epoch 19/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0152 - accuracy: 0.9952 - val_loss: 0.3226 - val_accuracy: 0.8667
# Epoch 20/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0217 - accuracy: 0.9904 - val_loss: 0.3030 - val_accuracy: 0.8778
# Epoch 21/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.4084 - val_accuracy: 0.8444
# Epoch 22/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0215 - accuracy: 0.9952 - val_loss: 0.3236 - val_accuracy: 0.8667
# Epoch 23/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0174 - accuracy: 0.9952 - val_loss: 0.3208 - val_accuracy: 0.8667
# Epoch 24/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0216 - accuracy: 0.9904 - val_loss: 0.3023 - val_accuracy: 0.8778
# Epoch 25/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 0.3544 - val_accuracy: 0.8556
# Epoch 26/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.3659 - val_accuracy: 0.8556
# Epoch 27/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0116 - accuracy: 0.9952 - val_loss: 0.3133 - val_accuracy: 0.8667
# Epoch 28/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.3037 - val_accuracy: 0.8778
# Epoch 29/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 0.3492 - val_accuracy: 0.8556
# Epoch 30/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0124 - accuracy: 0.9952 - val_loss: 0.3398 - val_accuracy: 0.8556
# Epoch 31/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0107 - accuracy: 0.9952 - val_loss: 0.3095 - val_accuracy: 0.8778
# Epoch 32/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.3310 - val_accuracy: 0.8556
# Epoch 33/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.3366 - val_accuracy: 0.8556
# Epoch 34/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.3459 - val_accuracy: 0.8556
# Epoch 35/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0290 - accuracy: 0.9904 - val_loss: 0.2992 - val_accuracy: 0.8889
# Epoch 36/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 0.5235 - val_accuracy: 0.8333
# Epoch 37/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0251 - accuracy: 0.9952 - val_loss: 0.3093 - val_accuracy: 0.8667
# Epoch 38/100
# 208/208 [==============================] - 3s 14ms/step - loss: 0.0116 - accuracy: 0.9952 - val_loss: 0.3104 - val_accuracy: 0.8667
# Epoch 39/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 0.3732 - val_accuracy: 0.8667
# Epoch 40/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0139 - accuracy: 0.9904 - val_loss: 0.3730 - val_accuracy: 0.8667
# Epoch 41/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0199 - accuracy: 0.9952 - val_loss: 0.4207 - val_accuracy: 0.8444
# Epoch 42/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0129 - accuracy: 0.9952 - val_loss: 0.3240 - val_accuracy: 0.8667
# Epoch 43/100
# 208/208 [==============================] - 3s 14ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.3070 - val_accuracy: 0.8667
# Epoch 44/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0143 - accuracy: 0.9904 - val_loss: 0.3741 - val_accuracy: 0.8667
# Epoch 45/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0113 - accuracy: 0.9952 - val_loss: 0.3331 - val_accuracy: 0.8556
# Epoch 46/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 0.3430 - val_accuracy: 0.8556
# Epoch 47/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 0.3824 - val_accuracy: 0.8667
# Epoch 48/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 0.3558 - val_accuracy: 0.8556
# Epoch 49/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0117 - accuracy: 0.9952 - val_loss: 0.3349 - val_accuracy: 0.8667
# Epoch 50/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0099 - accuracy: 0.9904 - val_loss: 0.3222 - val_accuracy: 0.8667
# Epoch 51/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0121 - accuracy: 0.9952 - val_loss: 0.3238 - val_accuracy: 0.8667
# Epoch 52/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0092 - accuracy: 0.9952 - val_loss: 0.3654 - val_accuracy: 0.8667
# Epoch 53/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0108 - accuracy: 0.9904 - val_loss: 0.3599 - val_accuracy: 0.8556
# Epoch 54/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0098 - accuracy: 0.9952 - val_loss: 0.3420 - val_accuracy: 0.8556
# Epoch 55/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0115 - accuracy: 0.9952 - val_loss: 0.3497 - val_accuracy: 0.8556
# Epoch 56/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0152 - accuracy: 0.9904 - val_loss: 0.3707 - val_accuracy: 0.8667
# Epoch 57/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0126 - accuracy: 0.9904 - val_loss: 0.3226 - val_accuracy: 0.8778
# Epoch 58/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0122 - accuracy: 0.9904 - val_loss: 0.3600 - val_accuracy: 0.8556
# Epoch 59/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.3552 - val_accuracy: 0.8556
# Epoch 60/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.3149 - val_accuracy: 0.8778
# Epoch 61/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.8333
# Epoch 62/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0194 - accuracy: 0.9952 - val_loss: 0.3626 - val_accuracy: 0.8556
# Epoch 63/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0084 - accuracy: 0.9952 - val_loss: 0.3231 - val_accuracy: 0.8667
# Epoch 64/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0110 - accuracy: 0.9904 - val_loss: 0.3327 - val_accuracy: 0.8667
# Epoch 65/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0093 - accuracy: 0.9952 - val_loss: 0.3356 - val_accuracy: 0.8556
# Epoch 66/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0117 - accuracy: 0.9904 - val_loss: 0.3524 - val_accuracy: 0.8556
# Epoch 67/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0259 - accuracy: 0.9952 - val_loss: 0.5479 - val_accuracy: 0.8333
# Epoch 68/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0240 - accuracy: 0.9952 - val_loss: 0.3896 - val_accuracy: 0.8667
# Epoch 69/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 0.3924 - val_accuracy: 0.8778
# Epoch 70/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0251 - accuracy: 0.9952 - val_loss: 0.3477 - val_accuracy: 0.8667
# Epoch 71/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0086 - accuracy: 0.9952 - val_loss: 0.4956 - val_accuracy: 0.8333
# Epoch 72/100
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.5206 - val_accuracy: 0.8333
# Epoch 73/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.3657 - val_accuracy: 0.8556
# Epoch 74/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0283 - accuracy: 0.9952 - val_loss: 0.3371 - val_accuracy: 0.8778
# Epoch 75/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0080 - accuracy: 0.9952 - val_loss: 0.4488 - val_accuracy: 0.8444
# Epoch 76/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0212 - accuracy: 0.9952 - val_loss: 0.5281 - val_accuracy: 0.8333
# Epoch 77/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0249 - accuracy: 0.9904 - val_loss: 0.3204 - val_accuracy: 0.8778
# Epoch 78/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0078 - accuracy: 0.9952 - val_loss: 0.3976 - val_accuracy: 0.8667
# Epoch 79/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.3677 - val_accuracy: 0.8556
# Epoch 80/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0092 - accuracy: 0.9952 - val_loss: 0.3157 - val_accuracy: 0.8778
# Epoch 81/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.3159 - val_accuracy: 0.8889
# Epoch 82/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 0.6162 - val_accuracy: 0.8333
# Epoch 83/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0249 - accuracy: 0.9952 - val_loss: 0.4710 - val_accuracy: 0.8667
# Epoch 84/100
# 208/208 [==============================] - 3s 14ms/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.3298 - val_accuracy: 0.8667
# Epoch 85/100
# 208/208 [==============================] - 2s 12ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.3224 - val_accuracy: 0.8889
# Epoch 86/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0079 - accuracy: 0.9952 - val_loss: 0.3699 - val_accuracy: 0.8667
# Epoch 87/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.4694 - val_accuracy: 0.8333
# Epoch 88/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0105 - accuracy: 0.9904 - val_loss: 0.3580 - val_accuracy: 0.8556
# Epoch 89/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0085 - accuracy: 0.9952 - val_loss: 0.3508 - val_accuracy: 0.8556
# Epoch 90/100
# 208/208 [==============================] - 3s 14ms/step - loss: 0.0076 - accuracy: 0.9952 - val_loss: 0.3550 - val_accuracy: 0.8556
# Epoch 91/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0089 - accuracy: 0.9952 - val_loss: 0.3483 - val_accuracy: 0.8556
# Epoch 92/100
# 208/208 [==============================] - 3s 15ms/step - loss: 0.0084 - accuracy: 0.9952 - val_loss: 0.3572 - val_accuracy: 0.8556
# Epoch 93/100
# 208/208 [==============================] - 3s 14ms/step - loss: 0.0081 - accuracy: 0.9904 - val_loss: 0.3699 - val_accuracy: 0.8556
# Epoch 94/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.4214 - val_accuracy: 0.8667
# Epoch 95/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0129 - accuracy: 0.9904 - val_loss: 0.3279 - val_accuracy: 0.8778
# Epoch 96/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0081 - accuracy: 0.9952 - val_loss: 0.3362 - val_accuracy: 0.8667
# Epoch 97/100
# 208/208 [==============================] - 3s 12ms/step - loss: 0.0080 - accuracy: 0.9952 - val_loss: 0.3626 - val_accuracy: 0.8556
# Epoch 98/100
# 208/208 [==============================] - 2s 11ms/step - loss: 0.0081 - accuracy: 0.9952 - val_loss: 0.3775 - val_accuracy: 0.8667
# Epoch 99/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0082 - accuracy: 0.9952 - val_loss: 0.3743 - val_accuracy: 0.8556
# Epoch 100/100
# 208/208 [==============================] - 3s 13ms/step - loss: 0.0074 - accuracy: 0.9952 - val_loss: 0.3556 - val_accuracy: 0.8556

# %%
count = 0
videoFile = "Tom and Jerry 3.mp4"
cap = cv2.VideoCapture(videoFile)
frameRate = cap.get(5) #frame rate
x=1
while(cap.isOpened()):
    frameId = cap.get(1) #current frame number
    ret, frame = cap.read()
    if (ret != True):
        break
    if (frameId % math.floor(frameRate) == 0):
        filename ="test%d.jpg" % count;count+=1
        cv2.imwrite(filename, frame)
cap.release()
print ("Done!")
# Out:
# Done!

# %%
test = pd.read_csv('test.csv')

# %%
test_image = []
for img_name in test.Image_ID:
    img = plt.imread('' + img_name)
    test_image.append(img)
test_img = np.array(test_image)

# %%
test_image = []
for i in range(0,test_img.shape[0]):
    a = resize(test_img[i], preserve_range=True, output_shape=(224,224)).astype(int)
    test_image.append(a)
test_image = np.array(test_image)

# %%
# preprocessing the images
test_image = preprocess_input(test_image, mode='tf')

# extracting features from the images using pretrained model
test_image = base_model.predict(test_image)

# converting the images to 1-D form
test_image = test_image.reshape(186, 7*7*512)

# zero centered images
test_image = test_image/test_image.max()

# %%
predictions = model.predict_classes(test_image)

# %%
print("The screen time of JERRY is", predictions[predictions==1].shape[0], "seconds")
print("The screen time of TOM is", predictions[predictions==2].shape[0], "seconds")
# Out:
# The screen time of JERRY is 6 seconds
# The screen time of TOM is 116 seconds
